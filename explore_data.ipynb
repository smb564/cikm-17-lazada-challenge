# %%
import pandas as pd

# %%
x = pd.read_csv("training/data_train.csv", header=None)
clarity = pd.read_csv("training/clarity_train.labels")
con = pd.read_csv("training/conciseness_train.labels")

# %%
clarity.columns = ["clarity"]
con.columns = ["conciseness"]
data = x.join(clarity).join(con)

# %%
data.loc[data.clarity==0].count()
# Out:
# 0              2055
# 1              2055
# 2              2055
# 3              2055
# 4              2055
# 5              1980
# 6              2053
# 7              2055
# 8              2041
# clarity        2055
# conciseness    2055
# dtype: int64

# %%
print("Clarity from total: ", int(data['clarity'].sum())," out of ", len(data))
print("Conciseness from total: ", int(data['conciseness'].sum())," out of ", len(data))
# Out:
# Clarity from total:  34227  out of  36283
# Conciseness from total:  24865  out of  36283

# %%
print("Concise given clarity: ", len(data[data.clarity == 1][data.conciseness == 1]), " out of ", len(data[data.clarity == 1]))
# Out:
# Concise given clarity:  24865  out of  34227
# /home/supun/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Key observation
# According to the training data, if a title is concise it must have clarity

# %%
# len(data[data.conciseness==0])
data[data.conciseness==0].head(20)
# Out:
#      0                   1                                                  2  \
# 1   my  AE068HBAA3RPRDANMY  Cuba Heartbreaker Eau De Parfum Spray 100ml/3.3oz
# 17  my  JI733ELAA3XWA1ANMY  JIANSE Cranes Sky Flight Couple Cloud Hard Bac...
# 22  my  KE294HLAA8EBUZANMY  DIY Marble Contact Paper PVC Removable Wallpap...
# 35  my  NO037ELAA6U4WOANMY  2.7 Inch1080P HD Car DVR Wide Angle Lens Car C...
# 37  my  NO037ELAA7NRV8ANMY  CHEER Portable Home Bluetooth 2.1 Stereo Recei...
# 40  my    NO037ELDWN2TANMY  Snake Print Pattern Phone Case for Motorola Mo...
# 41  my  NO037FAAA60MKQANMY  2016 New Arrive Women Four Seasons Flats Casua...
# 42  my  NO037FAAA7XIPYANMY  Toprank Women Sexy Strapless Sleeveless Solid ...
# 43  my  NO037FAAA8CLZ2ANMY                                         RUDY Dress
# 44  my  NO037FAAAAUD0YANMY  Women Canvas Navy Style ID Credit Card Bag Gir...
# 45  my    NO037FADCF82ANMY  Men's Leather Bifold Multi Pocket Credit ID Ca...
# ...

# %%
len(data[data.clarity==0])
# Out:
# 2055

# %%
import sys
print(sys.path)
# Out:
# ['', '/usr/lib/python35.zip', '/usr/lib/python3.5', '/usr/lib/python3.5/plat-x86_64-linux-gnu', '/usr/lib/python3.5/lib-dynload', '/home/supun/.local/lib/python3.5/site-packages', '/usr/local/lib/python3.5/dist-packages', '/usr/lib/python3/dist-packages', '/home/supun/.local/lib/python3.5/site-packages/IPython/extensions', '/home/supun/.ipython']
